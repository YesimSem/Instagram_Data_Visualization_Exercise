# %%
import pandas as pd 
import seaborn as sns
df = pd.read_excel('/Users/xxxx/Desktop/Instagram.xlsx')
df.head()
# Out:
#    Reach   Impression  ProfileVisit  Like  Comments  ImageID
# 0     143         173             0    14         0        1
# 1     233         276             5    20         0        2
# 2     187         205             0    13         0        3
# 3     245         264             5    27         0        4
# 4     201         223             0    19         0        5

# %%
sns.lmplot(x = 'Reach ', y = 'Impression', data = df, line_kws={'color': 'red'}, scatter_kws= {'color': 'black'})

# %%
sns.lmplot(x = 'Reach ', y = 'Like', data = df, line_kws={'color': 'red'}, scatter_kws= {'color': 'black'})

# %%
sns.lmplot(x = 'Impression', y = 'ProfileVisit', data = df, line_kws={'color': 'red'}, scatter_kws= {'color': 'black'})

# %%
sns.pairplot(df)

# %%
sns.distplot(df['Like'])

# %%
sns.jointplot(df['Reach '], df['Like'])

# %%
sns.countplot(x = 'Like', data = df)

# %%
from matplotlib import pyplot as plt
import seaborn as sns

plt.figure(figsize=(15,8))

sns.countplot(x = 'Like', data = df)

# %%
df.plot.scatter(x = 'Reach ', y = 'ImageID', c = 'Like', cmap = 'coolwarm')

# %%
df.plot.hexbin(x = 'Reach ', y = 'Like', gridsize = 25, cmap = 'rocket')
